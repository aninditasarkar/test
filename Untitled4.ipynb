# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/PlotDataSet.csv')
df.head(2) #View first 10 data rows
df.plot(kind="scatter", x="Algorithm_Name", y="Accuracy_Document")

# %% [markdown]
# # New section
